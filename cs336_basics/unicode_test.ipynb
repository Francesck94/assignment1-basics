# %%
ord('s')
# Out:
# 115

# %%
chr(115)
# Out:
# 's'

# %% [markdown]
# What Unicode character does chr(0) return?

# %%
chr(0)
# Out:
# '\x00'

# %%
chr(0).__repr__()
# Out:
# "'\\x00'"

# %%
print(chr(0))

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %% [markdown]
# # Unicode encodings

# %%
test_string = "hello! こんにちは!"

# %%
utf8_encoded = test_string.encode("utf-8")

# %%
print(utf8_encoded)
# Out:
# b'hello! \xe3\x81\x93\xe3\x82\x93\xe3\x81\xab\xe3\x81\xa1\xe3\x81\xaf!'

# %%
print(type(utf8_encoded))
# Out:
# <class 'bytes'>

# %%
list(utf8_encoded)
# Out:
# [104,
#  101,
#  108,
#  108,
#  111,
#  33,
#  32,
#  227,
#  129,
#  147,
#  227,
#  130,
#  147,
#  227,
#  129,
#  171,
#  227,
#  129,
#  161,
#  227,
#  129,
#  175,
#  33]

# %%
print(len(test_string))
# Out:
# 13

# %%
print(len(utf8_encoded))
# Out:
# 23

# %%
print(utf8_encoded.decode("utf-8"))
# Out:
# hello! こんにちは!

# %%
# test why is it incorrect
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# Out:
# 'hello'

# %%
print("£".encode("utf-8"))
# Out:
# b'\xc2\xa3'

# %% [markdown]
# example of errors

# %%
decode_utf8_bytes_to_str_wrong("£".encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 decode_utf8_bytes_to_str_wrong("£".encode("utf-8"))
#
# Cell In[9], line 3, in decode_utf8_bytes_to_str_wrong(bytestring)
#       2 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 3     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc2 in position 0: unexpected end of data

# %% [markdown]
# Give a two byte sequence that does not decode to any Unicode character(s).

# %%
incorrect_seq = b'\xf0\x9c'

# %%
incorrect_seq.decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 incorrect_seq.decode("utf-8")
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 0-1: unexpected end of data

# %% [markdown]
# byte_sequence = [b]
