# %%
import json

# %%
vocab_path = "../output/train_bpe_tinystories/vocab.json"

# %%
with open(vocab_path, "r") as f:
    vocab = json.load(f)

# %%
token_len = {k: len(k) for k in vocab}

# %%
longest_token = max(token_len, key=token_len.get)
longest_token
